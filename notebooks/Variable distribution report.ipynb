# %% [markdown]
# ## Variable distribution report

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pylab import *
import os
# %matplotlib inline

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv('../output/categorical.csv')

# %%
variable = data.ETNIA_PARTICIPANTE
variable.hist()
variable.value_counts()
# Out:
# 1    9841
# 6    1917
# 2      46
# 7      12
# 5       8
# 3       3
# 4       2
# Name: ETNIA_PARTICIPANTE, dtype: int64

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white", context="talk")
sns.distplot(variable, hist=True, color="r")
